# %%
import pandas as pd
data=pd.read_csv('/content/IPL_DATASET.csv')          # It shows the whole dataset.
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.head()                    # It shows by default the 5 data from head.
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1   2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2   3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3   4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4   5    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
data.tail()           # It shows by default the 5 data from tail.
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  22-05-2016     Delhi Daredevils
# 573  574    2016  Bangalore  24-05-2016        Gujarat Lions
# 574  575    2016      Delhi  25-05-2016  Sunrisers Hyderabad
# 575  576    2016      Delhi  27-05-2016        Gujarat Lions
# 576  577    2016  Bangalore  29-05-2016  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.describe()                    # It describes all dataset.
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.info()                   # It describes the informations of the whole dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
data[100:200]                     # It prints the data from 100 to 199.
# Out:
#       id  season            city        date                  team1  \
# 100  101    2009          Durban  14-05-2009       Rajasthan Royals
# 101  102    2009    Bloemfontein  15-05-2009       Delhi Daredevils
# 102  103    2009  Port Elizabeth  16-05-2009         Mumbai Indians
# 103  104    2009    Johannesburg  16-05-2009  Kolkata Knight Riders
# 104  105    2009    Johannesburg  17-05-2009        Kings XI Punjab
# ..   ...     ...             ...         ...                    ...
# 195  196    2011         Kolkata  20-04-2011   Kochi Tuskers Kerala
# 196  197    2011      Chandigarh  21-04-2011        Kings XI Punjab
# 197  198    2011          Mumbai  22-04-2011         Mumbai Indians
# 198  199    2011         Kolkata  22-04-2011  Kolkata Knight Riders
# 199  200    2011           Delhi  23-04-2011       Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[:25]                        # It prints the data from 0 to 25.
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 1    2    2008  Chandigarh  19-04-2008          Chennai Super Kings
# 2    3    2008       Delhi  19-04-2008             Rajasthan Royals
# 3    4    2008      Mumbai  20-04-2008               Mumbai Indians
# 4    5    2008     Kolkata  20-04-2008              Deccan Chargers
# 5    6    2008      Jaipur  21-04-2008              Kings XI Punjab
# 6    7    2008   Hyderabad  22-04-2008              Deccan Chargers
# 7    8    2008     Chennai  23-04-2008          Chennai Super Kings
# 8    9    2008   Hyderabad  24-04-2008              Deccan Chargers
# 9   10    2008  Chandigarh  25-04-2008              Kings XI Punjab
# 10  11    2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 11  12    2008     Chennai  26-04-2008        Kolkata Knight Riders
# 12  13    2008      Mumbai  27-04-2008               Mumbai Indians
# ...

# %%
data[:38]                       # It prints the data from 0 to 38
# Out:
#     id  season        city        date                        team1  \
# 0    1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 1    2    2008  Chandigarh  19-04-2008          Chennai Super Kings
# 2    3    2008       Delhi  19-04-2008             Rajasthan Royals
# 3    4    2008      Mumbai  20-04-2008               Mumbai Indians
# 4    5    2008     Kolkata  20-04-2008              Deccan Chargers
# 5    6    2008      Jaipur  21-04-2008              Kings XI Punjab
# 6    7    2008   Hyderabad  22-04-2008              Deccan Chargers
# 7    8    2008     Chennai  23-04-2008          Chennai Super Kings
# 8    9    2008   Hyderabad  24-04-2008              Deccan Chargers
# 9   10    2008  Chandigarh  25-04-2008              Kings XI Punjab
# 10  11    2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 11  12    2008     Chennai  26-04-2008        Kolkata Knight Riders
# 12  13    2008      Mumbai  27-04-2008               Mumbai Indians
# ...

# %%
data[300:]                         # It prints the data from 300 to 576.
# Out:
#       id  season       city        date                        team1  \
# 300  301    2012     Mumbai  09-05-2012               Mumbai Indians
# 301  302    2012     Jaipur  10-05-2012             Rajasthan Royals
# 302  303    2012       Pune  11-05-2012  Royal Challengers Bangalore
# 303  304    2012    Kolkata  12-05-2012               Mumbai Indians
# 304  305    2012    Chennai  12-05-2012             Delhi Daredevils
# ..   ...     ...        ...         ...                          ...
# 572  573    2016     Raipur  22-05-2016             Delhi Daredevils
# 573  574    2016  Bangalore  24-05-2016                Gujarat Lions
# 574  575    2016      Delhi  25-05-2016          Sunrisers Hyderabad
# 575  576    2016      Delhi  27-05-2016                Gujarat Lions
# 576  577    2016  Bangalore  29-05-2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data[:200]                      # It prints the data from 0 to 199.
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 195  196    2011     Kolkata  20-04-2011   Kochi Tuskers Kerala
# 196  197    2011  Chandigarh  21-04-2011        Kings XI Punjab
# 197  198    2011      Mumbai  22-04-2011         Mumbai Indians
# 198  199    2011     Kolkata  22-04-2011  Kolkata Knight Riders
# 199  200    2011       Delhi  23-04-2011       Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.isnull().sum()                      # It shows the sum of isnull value in the dataset.
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
data['winner'].describe()                     # It describes the winnerin the dataset.
# Out:
# count                574
# unique                13
# top       Mumbai Indians
# freq                  80
# Name: winner, dtype: object

# %%
data['season'].describe()                     # It describes the season in the dataset.
# Out:
# count     577.000000
# mean     2012.029463
# std         2.486247
# min      2008.000000
# 25%      2010.000000
# 50%      2012.000000
# 75%      2014.000000
# max      2016.000000
# Name: season, dtype: float64

# %%
data['win_by_runs'].describe()                       # It describes the win_by_runs in the dataset.
# Out:
# count    577.000000
# mean      13.715771
# std       23.619282
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       20.000000
# max      144.000000
# Name: win_by_runs, dtype: float64

# %%
data['win_by_wickets'].describe()                         # It describes the win_by_wickets in the dataset.
# Out:
# count    577.000000
# mean       3.363951
# std        3.416049
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       10.000000
# Name: win_by_wickets, dtype: float64

# %%
data['team1'].value_counts()                         # It count the values team1 in the dataset.
# Out:
# team1
# Chennai Super Kings            77
# Mumbai Indians                 76
# Kings XI Punjab                69
# Kolkata Knight Riders          62
# Royal Challengers Bangalore    62
# Delhi Daredevils               57
# Rajasthan Royals               54
# Deccan Chargers                43
# Sunrisers Hyderabad            37
# Pune Warriors                  20
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Gujarat Lions                   6
# Name: count, dtype: int64

# %%
data['team2'].value_counts()                           # It count the values team2 in the dataset.
# Out:
# team2
# Royal Challengers Bangalore    77
# Delhi Daredevils               76
# Kolkata Knight Riders          70
# Kings XI Punjab                65
# Rajasthan Royals               64
# Mumbai Indians                 64
# Chennai Super Kings            54
# Deccan Chargers                32
# Pune Warriors                  26
# Sunrisers Hyderabad            25
# Gujarat Lions                  10
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
data['date'].describe()                             # It counts the dates in the dataset.
# Out:
# count            577
# unique           407
# top       17-04-2011
# freq               2
# Name: date, dtype: object

# %%
data['toss_winner'].value_counts()                              # It counts the toss_winner in the dataset.
# Out:
# toss_winner
# Mumbai Indians                 74
# Kolkata Knight Riders          69
# Chennai Super Kings            66
# Kings XI Punjab                64
# Delhi Daredevils               64
# Rajasthan Royals               63
# Royal Challengers Bangalore    61
# Deccan Chargers                43
# Sunrisers Hyderabad            30
# Pune Warriors                  20
# Kochi Tuskers Kerala            8
# Gujarat Lions                   8
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
data['toss_decision'].value_counts()                            # It counts the toss_decision in the dataset.
# Out:
# toss_decision
# field    315
# bat      262
# Name: count, dtype: int64

# %%
data['umpire1'].describe()                                     # It describes the umpire1 in the dataset.
# Out:
# count                 577
# unique                 43
# top       HDPK Dharmasena
# freq                   73
# Name: umpire1, dtype: object

# %%
data['umpire2'].describe()                                   # It describes the umpire2 in the dataset.
# Out:
# count            577
# unique            45
# top       SJA Taufel
# freq              54
# Name: umpire2, dtype: object

# %%
data['team1'].max()                                     # It prints the max value of team1 in the dataset.
# Out:
# 'Sunrisers Hyderabad'

# %%
data['team1'].min()                                     # It prints the min value of team1 in the dataset.
# Out:
# 'Chennai Super Kings'

# %%
data['team2'].max()                                     # It prints the max value of team2 in the dataset.
# Out:
# 'Sunrisers Hyderabad'

# %%
data['team2'].min()                                     # It prints the min value of team2 in the dataset.
# Out:
# 'Chennai Super Kings'

# %%
data['toss_winner'].max()                               # It prints the max value of toss_winner in the dataset.
# Out:
# 'Sunrisers Hyderabad'

# %%
data['toss_winner'].min()                                # It prints the min value of toss_winner in the dataset.
# Out:
# 'Chennai Super Kings'

# %%
data['win_by_wickets'].max()                               # It prints the max value of win_by_wickets in the dataset.
# Out:
# 10

# %%
data['toss_decision'].mode()                               # It prints mode value of toss_decision in the dataset.
# Out:
# 0    field
# Name: toss_decision, dtype: object

# %%
data['umpire1'].mode()                                      # It prints mode value of umpire1 in the dataset.
# Out:
# 0    HDPK Dharmasena
# Name: umpire1, dtype: object

# %%
data.sort_values(by='win_by_wickets').head()             # It prints the sort_values of win_by_wickets form head in the dataset.
# Out:
#       id  season       city        date                        team1  \
# 0      1    2008  Bangalore  18-04-2008        Kolkata Knight Riders
# 324  325    2013  Hyderabad  05-04-2013          Sunrisers Hyderabad
# 323  324    2013  Bangalore  04-04-2013  Royal Challengers Bangalore
# 320  321    2012    Chennai  25-05-2012          Chennai Super Kings
# 319  320    2012  Bangalore  23-05-2012          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 324                Pune Warriors                Pune Warriors         field
# 323               Mumbai Indians               Mumbai Indians         field
# 320             Delhi Daredevils             Delhi Daredevils         field
# 319               Mumbai Indians               Mumbai Indians         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.sort_values(by='win_by_runs').tail()             # It prints the sort_values of win_by_runs form tail in the dataset.
# Out:
#       id  season        city        date                        team1  \
# 236  237    2011  Dharamsala  17-05-2011              Kings XI Punjab
# 351  352    2013   Bangalore  23-04-2013  Royal Challengers Bangalore
# 497  498    2015   Bangalore  06-05-2015  Royal Challengers Bangalore
# 0      1    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 560  561    2016   Bangalore  14-05-2016  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 236  Royal Challengers Bangalore              Kings XI Punjab           bat
# 351                Pune Warriors                Pune Warriors         field
# 497              Kings XI Punjab              Kings XI Punjab         field
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 560                Gujarat Lions                Gujarat Lions         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
import pandas as pd              # Define the pandas as pd
import numpy as np               # Define the Numpy as np
import seaborn as sns            # Define the Seaborn  as sns
data=pd.read_csv('/content/IPL_DATASET.csv')                     # print all the dataset by using pandas.
data
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
sns.pairplot(data)                   # print the pairplot of all dataset by using Seaborn library.

# %%
sns.pairplot(data,hue='winner')                         # print the pairplot of winner by using Seaborn library.

# %%
sns.pairplot(data,hue='toss_decision')         # print the pairplot of toss_decision by using Seaborn library.

# %%
sns.pairplot(data,hue='toss_winner')      # print the pairplot of toss_winner by using Seaborn library.

# %%
sns.pairplot(data,hue='result')       # print the pairplot of result by using Seaborn library.

# %%
sns.barplot(x='toss_winner',y='winner',data=data)  # print the barplot of toss_winner and winner by using Seaborn library.
# Out:
# <Axes: xlabel='toss_winner', ylabel='winner'>

# %%
sns.barplot(x='result',y='winner',data=data)  # print the barplot of result and winner by using Seaborn library.
# Out:
# <Axes: xlabel='result', ylabel='winner'>

# %%
sns.barplot(x='team1',y='team2',data=data)    # print the barplot of team1 and team2 by using Seaborn library.
# Out:
# <Axes: xlabel='team1', ylabel='team2'>

# %%
sns.barplot(x='winner',y='win_by_wickets',data=data) # print the barplot of winner and win_by_wickets by using Seaborn library.
# Out:
# <Axes: xlabel='winner', ylabel='win_by_wickets'>

# %%
sns.barplot(x='winner',y='win_by_runs',data=data)         # print the barplot of winner and win_by_runs by using Seaborn library.
# Out:
# <Axes: xlabel='winner', ylabel='win_by_runs'>

# %%
sns.countplot(x='winner',data=data)                              # print the countplot of winner by using Seaborn library.
# Out:
# <Axes: xlabel='winner', ylabel='count'>

# %%
sns.countplot(x='venue',data=data)                   # print the countplot of venue by using Seaborn library.
# Out:
# <Axes: xlabel='venue', ylabel='count'>

# %%
sns.boxplot(x='winner',data=data)                           # print the boxplot of winner by using Seaborn library.
# Out:
# <Axes: xlabel='winner'>

# %%
sns.boxplot(x='team1',data=data)                   # print the boxplot of team1 by using Seaborn library.
# Out:
# <Axes: xlabel='team1'>

# %%
sns.boxplot(x='team1', y='team2',data=data)                 # print the boxplot of team1 and team2  by using Seaborn library.
# Out:
# <Axes: xlabel='team1', ylabel='team2'>

# %%
sns.boxplot(x='win_by_runs', y='winner',data=data)            # print the boxplot of win_by_runs and winner  by using Seaborn library.
# Out:
# <Axes: xlabel='win_by_runs', ylabel='winner'>

# %%
import matplotlib.pyplot as plt                 # Define the matplotlib.pyplot library as plt.
data=[30,22,16,12,5,1]
plt.plot(data)
plt.show()

# %%
data=[1,8,6,7,4,9,3,10]
plt.plot(data)
plt.plot(data,'*')
plt.show()                                  # print the data by matplotlib.pyplot library

# %%
data=pd.read_csv('/content/IPL_DATASET.csv')
data.plot()
plt.show()                                        # print the dataset by using  matplotlib.pyplot library

# %%
sns.scatterplot(x='winner',y='win_by_runs',data=data)                # print the scatterplot of winner and win_by_runs by using Seaborn library
# Out:
# <Axes: xlabel='winner', ylabel='win_by_runs'>

# %%
sns.scatterplot(x='winner',y='win_by_wickets',data=data)    # print the scatterplot of winner and win_by_wickets by using Seaborn library
# Out:
# <Axes: xlabel='winner', ylabel='win_by_wickets'>

# %%
sns.scatterplot(x='win_by_runs',y='win_by_wickets',data=data)      # print the scatterplot of win_by_runs and win_by_wickets by using Seaborn library
# Out:
# <Axes: xlabel='win_by_runs', ylabel='win_by_wickets'>

# %%
sns.scatterplot(x='team1',y='team2',data=data)     # print the scatterplot of team1 and team2 by using Seaborn library
# Out:
# <Axes: xlabel='team1', ylabel='team2'>

# %%
sns.histplot(data=data,x='winner')                    # print the histplot of winner by using Seaborn library
# Out:
# <Axes: xlabel='winner', ylabel='Count'>

# %%
sns.histplot(data=data,x='team1',y='team2')                         # print the histplot of team1 and team2  by using Seaborn library
# Out:
# <Axes: xlabel='team1', ylabel='team2'>

# %%
sns.histplot(data=data,x='toss_winner')                                # print the histplot of toss_winner by using Seaborn library
# Out:
# <Axes: xlabel='toss_winner', ylabel='Count'>

# %%
sns.histplot(data=data,x='win_by_wickets')                           # print the histplot of win_by_wickets by using Seaborn library
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='Count'>

# %%
data['win_by_wickets'].fillna(data['win_by_wickets'].mean(),inplace=True)            # print the sum of null values of win_by_wickets and win_by_wickets
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
data.isnull().sum().value_counts()                       # print the count values of the dataset.
# Out:
# 0      14
# 3       2
# 7       1
# 577     1
# Name: count, dtype: int64

# %%
data.isnull()                             # print the isnull values in the dataset.
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 572  False   False  False  False  False  False        False          False
# 573  False   False  False  False  False  False        False          False
# 574  False   False  False  False  False  False        False          False
# 575  False   False  False  False  False  False        False          False
# 576  False   False  False  False  False  False        False          False
#
# ...

# %%
data.isnull().sum()                     # print the sum of null values in the whole dataset.
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
win_by_wickets=data['win_by_wickets']
plt.plot(win_by_wickets)                           # print the plot of win_by._wickets in the dataset.
plt.show()

# %%
win_by_runs=data['win_by_runs']
plt.plot(win_by_runs)                  # print the plot of win_by._runs in the dataset.
plt.show()
